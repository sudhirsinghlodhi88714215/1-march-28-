# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_csv('24marchwinequality-red.csv')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
da=pd.read_csv('24marchwinequality-red.csv')

# %%
da.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
da.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
da
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.distplot(da['fixed acidity'])
# Out:
# /tmp/ipykernel_295/3223264765.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(da['fixed acidity'])
# <AxesSubplot: xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(da['chlorides'], kde=True)
# Out:
# /tmp/ipykernel_295/1585124511.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(da['chlorides'], kde=True)
# <AxesSubplot: xlabel='chlorides', ylabel='Density'>

# %%
sns.scatterplot(x='alcohol',hue='quality',y='pH',data=da)
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='pH'>

# %%
sns.heatmap(data=da,annot=True)
# Out:
# <AxesSubplot: >

# %%
da['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
da
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
da['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
sns.histplot(data=da,x='chlorides',y='total sulfur dioxide',)
# Out:
# <AxesSubplot: xlabel='chlorides', ylabel='total sulfur dioxide'>

# %%
sns.histplot(data=da,x='chlorides',y='pH',kde=True)
# Out:
# <AxesSubplot: xlabel='chlorides', ylabel='pH'>

# %% [markdown]
# Q2.How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %%
import pandas as pd

# %%
pd.read_csv('24marchwinequality-red.csv')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
da = pd.read_csv('24marchwinequality-red.csv')

# %%
da.shape
# Out:
# (1599, 12)

# %%
da.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
#  analyzing these factors using statistical techniques?

# %%
import  pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_csv('exams.csv')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group C                 high school      standard
# 1      male        group B            some high school      standard
# 2    female        group C          associate's degree      standard
# 3      male        group E            some high school      standard
# 4      male        group C            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 995  female        group D            some high school      standard
# 996  female        group D          associate's degree  free/reduced
# 997    male        group A          associate's degree      standard
# 998  female        group C                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
da=pd.read_csv('exams.csv')

# %% [markdown]
# ## Insights or Observation
# ther are no missing values

# %%
da.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
## check datatypes
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
da.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.467000      69.419000      68.084000
# std      15.497842      14.976306      15.411634
# min      22.000000      21.000000      19.000000
# 25%      56.000000      59.000000      58.000000
# 50%      66.000000      70.000000      68.000000
# 75%      78.000000      81.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
da
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group C                 high school      standard
# 1      male        group B            some high school      standard
# 2    female        group C          associate's degree      standard
# 3      male        group E            some high school      standard
# 4      male        group C            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 995  female        group D            some high school      standard
# 996  female        group D          associate's degree  free/reduced
# 997    male        group A          associate's degree      standard
# 998  female        group C                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
da['total_score']=(da['math score']+da['reading score']+da['writing score'])
da['Average_score']=da['total_score']/3

# %%
da
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group C                 high school      standard
# 1      male        group B            some high school      standard
# 2    female        group C          associate's degree      standard
# 3      male        group E            some high school      standard
# 4      male        group C            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 995  female        group D            some high school      standard
# 996  female        group D          associate's degree  free/reduced
# 997    male        group A          associate's degree      standard
# 998  female        group C                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
fig,axis=plt.subplots(1,2,figsize=(25,8))
plt.subplot(121)
sns.histplot(data=da,x='Average_score',bins=40,kde=True,hue='gender')

plt.subplot(122)
sns.histplot(data=da,x='parental level of education	',bins=40,kde=True,hue='math score')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[191], line 6
#       3 sns.histplot(data=da,x='Average_score',bins=40,kde=True,hue='gender')
#       5 plt.subplot(122)
# ----> 6 sns.histplot(data=da,x='parental level of education	',bins=40,kde=True,hue='math score')
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/distributions.py:1395, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1374 def histplot(
#    1375     data=None, *,
#    1376     # Vector variables
#    (...)
#    1392     **kwargs,
#    1393 ):
# -> 1395     p = _DistributionPlotter(
#    1396         data=data,
# ...

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %%
da
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
da.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
da=da[da.duplicated()]

# %%
da.drop_duplicates(inplace=True)

# %%
da.duplicated()
# Out:
# 238     False
# 277     False
# 383     False
# 644     False
# 701     False
# 753     False
# 848     False
# 856     False
# 950     False
# 1117    False
# 1206    False
# 1326    False
# 1338    False
# 1341    False
# 1561    False
# 1564    False
# dtype: bool

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 238 to 1564
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         16 non-null     float64
#  1   volatile acidity      16 non-null     float64
#  2   citric acid           16 non-null     float64
#  3   residual sugar        16 non-null     float64
#  4   chlorides             16 non-null     float64
#  5   free sulfur dioxide   16 non-null     float64
#  6   total sulfur dioxide  16 non-null     float64
#  7   density               16 non-null     float64
#  8   pH                    16 non-null     float64
#  9   sulphates             16 non-null     float64
#  10  alcohol               16 non-null     float64
#  11  quality               16 non-null     int64
# dtypes: float64(11), int64(1)
# memory usage: 1.6 KB

# %%
da.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
X=da[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol',]]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 238             7.2             0.630         0.00             1.9      0.097
# 277            11.5             0.180         0.51             4.0      0.104
# 383             8.3             0.260         0.42             2.0      0.080
# 644             9.9             0.540         0.45             2.3      0.071
# 701             7.0             0.650         0.02             2.1      0.066
# 753             8.3             0.650         0.10             2.9      0.089
# 848             6.4             0.640         0.21             1.8      0.081
# 856             9.3             0.360         0.39             1.5      0.080
# 950             8.9             0.120         0.45             1.8      0.075
# 1117            7.0             0.690         0.07             2.5      0.091
# 1206            7.2             0.360         0.46             2.1      0.074
# ...

# %%
Y=da[['quality']]

# %%
Y
# Out:
#       quality
# 238         6
# 277         6
# 383         6
# 644         5
# 701         6
# 753         5
# 848         5
# 856         6
# 950         7
# 1117        6
# 1206        7
# 1326        6
# 1338        5
# 1341        6
# 1561        5
# 1564        5

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(X,Y,test_size=0.30,random_state=40)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((11, 11), (5, 11), (11, 1), (5, 1))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit_transform(x_train)
# Out:
# array([[ 1.09651155,  0.36461711,  1.0189019 ,  0.09471575, -1.04051389,
#         -0.0810252 , -0.0240942 ,  1.48659422,  0.16317969, -0.48724744,
#         -0.99529911],
#        [-0.86858499,  1.12615918, -1.30842593,  0.39239381,  0.98526536,
#         -0.18005601, -0.65355517, -0.90611457,  0.07343086, -0.64966326,
#          1.34197632],
#        [-0.86858499,  0.92308129, -1.61465328, -0.20296232, -1.5469587 ,
#         -0.87327163, -0.52103707,  0.1415804 ,  0.88117035, -0.08120791,
#         -0.87228461],
#        [ 2.18070275, -1.46308385,  1.38637471,  2.62497929,  2.30202188,
#         -1.26939484, -0.58729612,  1.84054522, -0.82405746,  2.35502931,
#         -0.13419763],
#        [ 0.01232035, -1.05692808,  0.83516549, -0.35180135, -0.12891323,
#         -0.57617922, -0.45477802,  0.2831608 , -1.45229928,  0.97449489,
#         -0.99529911],
#        [-0.32648939,  0.66923394, -0.14476202, -0.35180135, -0.12891323,
# ...

# %%
x_train_sc=scaler.fit_transform(x_train)

# %%
x_test_sc=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import  r2_score
linear=LinearRegression()
linear.fit(x_train_sc,y_train)
x_pred=linear.predict(x_test_sc)
mae=mean_absolute_error(y_test,x_pred)
score=r2_score(y_test,x_pred)
print( 'mean_absolute_error',mae)
print('r2 score',score)
# Out:
# mean_absolute_error 0.7447786889565642
# r2 score -0.41392676535522077

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
da
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 238             7.2             0.630         0.00             1.9      0.097
# 277            11.5             0.180         0.51             4.0      0.104
# 383             8.3             0.260         0.42             2.0      0.080
# 644             9.9             0.540         0.45             2.3      0.071
# 701             7.0             0.650         0.02             2.1      0.066
# 753             8.3             0.650         0.10             2.9      0.089
# 848             6.4             0.640         0.21             1.8      0.081
# 856             9.3             0.360         0.39             1.5      0.080
# 950             8.9             0.120         0.45             1.8      0.075
# 1117            7.0             0.690         0.07             2.5      0.091
# 1206            7.2             0.360         0.46             2.1      0.074
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 238 to 1564
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         16 non-null     float64
#  1   volatile acidity      16 non-null     float64
#  2   citric acid           16 non-null     float64
#  3   residual sugar        16 non-null     float64
#  4   chlorides             16 non-null     float64
#  5   free sulfur dioxide   16 non-null     float64
#  6   total sulfur dioxide  16 non-null     float64
#  7   density               16 non-null     float64
#  8   pH                    16 non-null     float64
#  9   sulphates             16 non-null     float64
#  10  alcohol               16 non-null     float64
#  11  quality               16 non-null     int64
# dtypes: float64(11), int64(1)
# memory usage: 1.6 KB

# %%
da.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      16.000000         16.000000    16.000000       16.000000
# mean        7.887500          0.490313     0.233125        2.106250
# std         1.432888          0.184576     0.189305        0.625533
# min         6.000000          0.120000     0.000000        1.400000
# 25%         7.000000          0.360000     0.057500        1.775000
# 50%         7.350000          0.525000     0.225000        2.000000
# 75%         8.450000          0.642500     0.427500        2.150000
# max        11.500000          0.695000     0.510000        4.000000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  16.000000            16.000000             16.000000  16.000000
# mean    0.080125            16.437500             37.937500   0.996526
# std     0.011477             9.018268             26.654502   0.001472
# ...

# %%
da.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 238            7.2              0.63         0.00             1.9      0.097
# 277           11.5              0.18         0.51             4.0      0.104
# 383            8.3              0.26         0.42             2.0      0.080
# 644            9.9              0.54         0.45             2.3      0.071
# 701            7.0              0.65         0.02             2.1      0.066
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 238                 14.0                  38.0  0.99675  3.37       0.58
# 277                  4.0                  23.0  0.99960  3.28       0.97
# 383                 11.0                  27.0  0.99740  3.21       0.80
# 644                 16.0                  40.0  0.99910  3.39       0.62
# 701                  8.0                  25.0  0.99720  3.47       0.67
#
#      alcohol  quality
# 238      9.0        6
# ...

# %%
da.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1326            6.7             0.460         0.24             1.7      0.077
# 1338            6.0             0.500         0.00             1.4      0.057
# 1341            7.5             0.510         0.02             1.7      0.084
# 1561            7.8             0.600         0.26             2.0      0.080
# 1564            7.2             0.695         0.13             2.0      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1326                 18.0                  34.0  0.99480  3.39       0.60
# 1338                 15.0                  26.0  0.99448  3.36       0.45
# 1341                 13.0                  31.0  0.99538  3.36       0.54
# 1561                 31.0                 131.0  0.99622  3.21       0.52
# 1564                 12.0                  20.0  0.99546  3.29       0.54
#
#       alcohol  quality
# 1326     10.6        6
# ...
